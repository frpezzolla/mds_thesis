# %%
# Cell: Inspect first person’s *valid* responses (exclude "-9" and blanks)
import os
import pandas as pd
import chardet
import json

# ── 1) Paths (relative to this notebook) ────────────────────────────────────
RAW_DATA = os.path.join("..","data","raw","cep_base_consolidada_2010_ahora.csv")
RAW_DICT = os.path.join("..","data","raw","cep_diccionario_de_variables_base_consolidada.csv")

# ── 2) Detect encoding of the dictionary ────────────────────────────────────
with open(RAW_DICT, "rb") as f:
    sample = f.read(100_000)
enc = chardet.detect(sample)["encoding"]

# ── 3) Load & normalize dictionary columns ─────────────────────────────────
dict_df = pd.read_csv(
    RAW_DICT,
    dtype=str,
    keep_default_na=False,
    encoding=enc,
    encoding_errors="replace"
)

# Fuzzy‐find the key columns
cols_lower = {c: c.lower() for c in dict_df.columns}
def pick(*keywords):
    for col, low in cols_lower.items():
        if any(k in low for k in keywords):
            return col
    raise KeyError(f"No column matches {keywords}")

dict_df = dict_df.rename(columns={
    pick("variab"):     "variable",
    pick("pregunt"):    "pregunta",
    pick("alternat"):   "alternativa",
    pick("etiquet"):    "etiqueta"
})[["variable","pregunta","alternativa","etiqueta"]]

# ── 4) Load only the first person from the data ─────────────────────────────
data_df = pd.read_csv(
    RAW_DATA,
    dtype=str,
    keep_default_na=False,
    nrows=1,
    encoding_errors="replace"
).reset_index().rename(columns={"index":"row_id"})

# ── 5) Melt to long form & join metadata ──────────────────────────────────
long = data_df.melt(
    id_vars="row_id",
    var_name="variable",
    value_name="valor"
)
joined = long.merge(dict_df, on="variable", how="left")

# ── 6) Exclude rows where alternativa is "-9" or "" ───────────────────────
valid = joined[~joined["alternativa"].isin([""])]

# ── 7) Build a JSON-like dict for that first person ──────────────────────
person0 = {"row_id": 0}
for _, row in valid.iterrows():
    person0[row["variable"]] = {
        "valor":       row["valor"],
        "pregunta":    row["pregunta"],
        "alternativa": row["alternativa"],
        "etiqueta":    row["etiqueta"]
    }

# ── 8) Pretty-print the result ────────────────────────────────────────────
print(json.dumps(person0, ensure_ascii=False, indent=2))
# Out:
# {
#   "row_id": 0,
#   "aleatorio_deck": {
#     "valor": "",
#     "pregunta": "",
#     "alternativa": "30",
#     "etiqueta": ""
#   },
#   "aleatorio_deck_1": {
#     "valor": "",
#     "pregunta": "Aleatorio Deck 1",
#     "alternativa": "119",
#     "etiqueta": ""
#   },
#   "aleatorio_deck_2": {
#     "valor": "",
#     "pregunta": "Aleatorio Deck 2",
#     "alternativa": "120",
#     "etiqueta": ""
#   },
#   "aleatorio_deck_3": {
#     "valor": "",
#     "pregunta": "Aleatorio Deck 3",
#     "alternativa": "118",
#     "etiqueta": ""
#   },
#   "aleatorio_deck_4": {
#     "valor": "",
#     "pregunta": "Aleatorio Deck 4",
#     "alternativa": "114",
#     "etiqueta": ""
#   },
#   "anomia_1_a": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? Actualmente, las personas deberían vivir el día a día y no preocuparse por el mañana.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_1_b": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? Contrario a lo que se dice, las cosas están empeorando y no mejorando.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_1_c": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? No son momentos para traer más niños al mundo.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_1_d": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? En general, las autoridades están preocupadas de los problemas de la gente común.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_1_e": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? Hoy en día, uno no sabe en quién confiar.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_1_f": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? Al fin de cuentas, la sociedad chilena está unida y sus conflictos son acotados.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_1_g": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? En general, los niveles de respeto y tolerancia son muy bajos.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_1_h": {
#     "valor": "",
#     "pregunta": "Qué tan de acuerdo está con las siguientes afirmaciones? En Chile, las cosas se hacen mal.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_a": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo Me siento solo.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_b": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo Estoy seguro que existen personas que se preocupan por mí.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_c": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo En general, no me siento discriminado.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_d": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo Me gusta vivir en sociedad.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_e": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo A veces siento que mi mundo más cercano se cae a pedazos.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_f": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo En general, me resulta fácil distinguir lo que está bien de lo que está mal.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_g": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo Me gustaría ser alguien importante.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_h": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo En nuestro país, hay muchas oportunidades para progresar.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_i": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo Las generaciones que vienen después de nosotros tendrán un mejor país para vivir.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_2_j": {
#     "valor": "",
#     "pregunta": "Para cada una de las siguientes afirmaciones, por favor, dígame en qué grado usted está de acuerdo o en desacuerdo Las cosas en nuestro país están cada vez peor.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_3": {
#     "valor": "",
#     "pregunta": "¿Cuán de acuerdo o en desacuerdo está con la siguiente afirmación? “En Chile es difícil que las personas hagan algo por los demás si no esperan recibir algo a cambio”",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_4_a": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está Ud. con las siguientes afirmaciones? El Estado trabaja por el bienestar de las personas",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_4_b": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está Ud. con las siguientes afirmaciones? En temas de orden público, el Estado usa su poder legítimamente",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_4_c": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está Ud. con las siguientes afirmaciones? Las personas piensan en sí mismas y no ayudan a otros que lo necesitan",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_4_d": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está Ud. con las siguientes afirmaciones? Los políticos no se preocupan por los problemas de las personas",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_4_e": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está Ud. con las siguientes afirmaciones? Las personas piensan que la honestidad no funciona siempre; ser deshonesto a veces es una buena forma de salir adelante",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_4_f": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está Ud. con las siguientes afirmaciones? La mayoría de las personas son amigas de otras por interés propio",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "anomia_4_g": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está Ud. con las siguientes afirmaciones? Las autoridades protegen a los más vulnerables y débiles",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_1": {
#     "valor": "",
#     "pregunta": "En general, considerando todos los aspectos de su vida, ¿cuán satisfecho se encuentra Ud. actualmente?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_10_a": {
#     "valor": "",
#     "pregunta": "Y en la misma escala, ¿cuán satisfechos con sus vidas cree usted que se encuentran las siguientes personas de su entorno cercano? Su familia.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_10_b": {
#     "valor": "",
#     "pregunta": "Y en la misma escala, ¿cuán satisfechos con sus vidas cree usted que se encuentran las siguientes personas de su entorno cercano? Sus amigos cercanos.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_10_c": {
#     "valor": "",
#     "pregunta": "Y en la misma escala, ¿cuán satisfechos con sus vidas cree usted que se encuentran las siguientes personas de su entorno cercano? Sus compañeros de trabajo o estudio.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_11_a": {
#     "valor": "",
#     "pregunta": "Y en la misma escala, ¿cuán satisfechos con sus vidas cree usted que se encuentran: Las personas que realizan su misma actividad, profesión u oficio",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_11_b": {
#     "valor": "",
#     "pregunta": "Y en la misma escala, ¿cuán satisfechos con sus vidas cree usted que se encuentran: El resto de los chilenos",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_a": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La educación básica y media.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_b": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La educación universitaria.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_c": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La atención en los consultorios y hospitales.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_d": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La atención por FONASA.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_e": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? El transporte público.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_f": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? Las carreteras, caminos, puentes e infraestructura pública en general.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_g": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La administración de la justicia.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_h": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La seguridad ciudadana.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_i": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La atención en las clínicas.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_j": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? La atención por ISAPRE.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_k": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? Los supermercados y tiendas comerciales.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_l": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? Las pensiones.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_m": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? Las instituciones financieras (bancos, cajas de compensación).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_n": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? Las farmacias.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_o": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? Las empresas de telefonía celular.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_12_p": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho” e independientemente de que los utilice o no, ¿cuán satisfecho está usted con el funcionamiento de los siguientes servicios? Las empresas de agua potable, gas y electricidad.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_a": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Pagar sus deudas.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_b": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Ayudar a un miembro de su familia en caso que alguno tenga un problema financiero.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_c": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Enfrentar alguna enfermedad grave y no ser capaz de pagar los costos no cubiertos por el sistema de salud.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_d": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Perder el trabajo.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_e": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Encontrar un trabajo.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_f": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Pagar la educación de sus hijos.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_g": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Que alguien de su familia o usted sean víctimas de un delito violento (robos, agresión).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_h": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Tener una pensión adecuada al momento de jubilarse [en la vejez].",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_i": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Que alguien de su familia o Ud. sean víctimas de balaceras.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_j": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Que alguien de su familia o Ud. sean víctimas de un secuestro.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_13_k": {
#     "valor": "",
#     "pregunta": "Considerando la misma escala, en términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted las siguientes situaciones? Que alguien de su familia o Ud. sean víctimas de violencia sexual.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_14_a": {
#     "valor": "",
#     "pregunta": "A veces, las épocas difíciles de la vida se facilitan porque las personas pueden contar con un familiar o amigo para apoyarlas cuando sea necesario. Si usted enfrentara un período de dificultad económica, ¿Cuán confiado estaría en una escala de 0 a 10, dónde 0 es nada confiado y 10 muy confiado, que podría recibir el apoyo necesario, de un familiar o amigo, en los siguientes casos? No pueda pagar las deudas.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_14_b": {
#     "valor": "",
#     "pregunta": "A veces, las épocas difíciles de la vida se facilitan porque las personas pueden contar con un familiar o amigo para apoyarlas cuando sea necesario. Si usted enfrentara un período de dificultad económica, ¿Cuán confiado estaría en una escala de 0 a 10, dónde 0 es nada confiado y 10 muy confiado, que podría recibir el apoyo necesario, de un familiar o amigo, en los siguientes casos? Tiene que enfrentar alguna enfermedad grave y no pueda pagar los costos no cubiertos por el sistema de salud.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_14_c": {
#     "valor": "",
#     "pregunta": "A veces, las épocas difíciles de la vida se facilitan porque las personas pueden contar con un familiar o amigo para apoyarlas cuando sea necesario. Si usted enfrentara un período de dificultad económica, ¿Cuán confiado estaría en una escala de 0 a 10, dónde 0 es nada confiado y 10 muy confiado, que podría recibir el apoyo necesario, de un familiar o amigo, en los siguientes casos? No pueda encontrar un trabajo.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_14_d": {
#     "valor": "",
#     "pregunta": "A veces, las épocas difíciles de la vida se facilitan porque las personas pueden contar con un familiar o amigo para apoyarlas cuando sea necesario. Si usted enfrentara un período de dificultad económica, ¿Cuán confiado estaría en una escala de 0 a 10, dónde 0 es nada confiado y 10 muy confiado, que podría recibir el apoyo necesario, de un familiar o amigo, en los siguientes casos? No pueda pagar la educación de sus hijos.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_14_e": {
#     "valor": "",
#     "pregunta": "A veces, las épocas difíciles de la vida se facilitan porque las personas pueden contar con un familiar o amigo para apoyarlas cuando sea necesario. Si usted enfrentara un período de dificultad económica, ¿Cuán confiado estaría en una escala de 0 a 10, dónde 0 es nada confiado y 10 muy confiado, que podría recibir el apoyo necesario, de un familiar o amigo, en los siguientes casos? Sea víctima de un delito violento (robos, agresión).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_14_f": {
#     "valor": "",
#     "pregunta": "A veces, las épocas difíciles de la vida se facilitan porque las personas pueden contar con un familiar o amigo para apoyarlas cuando sea necesario. Si usted enfrentara un período de dificultad económica, ¿Cuán confiado estaría en una escala de 0 a 10, dónde 0 es nada confiado y 10 muy confiado, que podría recibir el apoyo necesario, de un familiar o amigo, en los siguientes casos? No tenga una pensión adecuada al momento de jubilarse.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_15": {
#     "valor": "",
#     "pregunta": "Nos gustaría que piense en la seguridad económica de usted y de su familia. Por seguridad económica le pedimos que entienda la seguridad asociada a tener un trabajo, mantener su ingreso, pagar sus deudas y cuando corresponda una jubilación razonable. En términos generales, en una escala de 0 a 10, donde 0 es nada preocupado y 10 muy preocupado, ¿cuán preocupado está usted de su seguridad económica?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_a": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … Tengan problemas para pagar sus deudas en los próximos doce meses?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_b": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … Tengan que ayudar a un miembro de familia en caso que éste tenga un problema financiero en los próximos doce meses?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_c": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … Enfrenten, dentro de los próximos doce meses, alguna enfermedad grave y no sean capaces de pagar los costos no cubiertos por el sistema de salud?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_d": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … Pierdan su trabajo durante los próximos meses?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_e": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … No puedan encontrar trabajo, en caso de buscarlo, en los próximos doce meses?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_f": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … No puedan pagar los gastos de educación de sus hijos en los próximos doce meses?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_g": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … Sea víctimas de un delito violento (robos, agresión) en los próximos doce meses?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_16_h": {
#     "valor": "",
#     "pregunta": "En una escala de 0 a 10, donde 0 es muy improbable y 10 muy probable, ¿qué tan probable es que otras personas como usted … No tenga una pensión adecuada al momento de jubilarse?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_a": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …?  El colegio, escuela o liceo donde estudian sus hijos.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_b": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …?  La universidad, instituto profesional o centro de formación técnica donde estudian sus hijos (o usted).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_c": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? La atención recibida en su consultorio u hospital.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_d": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? La atención de salud entregada por su plan de FONASA.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_e": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? La atención recibida en su clínica.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_f": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? La atención de salud entregada por su ISAPRE.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_g": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? Los supermercados y tiendas comerciales donde usted hace sus compras.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_h": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? Las pensiones entregadas por su AFP.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_i": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? El banco donde usted tiene su cuenta.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_j": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? Las farmacias donde usted compra sus remedios.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_k": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? La empresa que le provee de telefonía celular.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_17_l": {
#     "valor": "",
#     "pregunta": "En general, en una escala de 0 a 10 donde 0 significa “totalmente insatisfecho” y 10 significa “totalmente satisfecho”, ¿cuán satisfecho está usted con: …? Las empresas que le proveen a su hogar agua potable, gas y electricidad.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_18_a": {
#     "valor": "",
#     "pregunta": "Ahora me gustaría que recordara si alguna vez, usted o algún miembro de su familia: Ha permanecido mucho tiempo sin pagar las deudas.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_18_b": {
#     "valor": "",
#     "pregunta": "Ahora me gustaría que recordara si alguna vez, usted o algún miembro de su familia: Ha tenido que pagar un gran costo ayudando a un miembro de su familia.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_18_c": {
#     "valor": "",
#     "pregunta": "Ahora me gustaría que recordara si alguna vez, usted o algún miembro de su familia: Ha tenido que gastar mucho dinero como resultado de una enfermedad o lesión grave de usted o un miembro de su familia.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_18_d": {
#     "valor": "",
#     "pregunta": "Ahora me gustaría que recordara si alguna vez, usted o algún miembro de su familia: Ha estado desempleado, no por elección propia.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_18_e": {
#     "valor": "",
#     "pregunta": "Ahora me gustaría que recordara si alguna vez, usted o algún miembro de su familia: Ha tenido que gastar mucho dinero en el pago de la educación de sus hijos.",
#     "alternativa": "-8",
#     "etiqueta": "No sabe (no leer)"
#   },
#   "bienestar_18_f": {
#     "valor": "",
#     "pregunta": "Ahora me gustaría que recordara si alguna vez, usted o algún miembro de su familia: Ha sido víctima de un delito violento (robos, agresión).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_18_g": {
#     "valor": "",
#     "pregunta": "Ahora me gustaría que recordara si alguna vez, usted o algún miembro de su familia: Ha tenido problemas de ingresos en la vejez.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_19_a": {
#     "valor": "",
#     "pregunta": "Durante los últimos doce meses, ¿ha experimentado usted malos tratos en alguno de estos lugares?   En su lugar de trabajo",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_19_b": {
#     "valor": "",
#     "pregunta": "Durante los últimos doce meses, ¿ha experimentado usted malos tratos en alguno de estos lugares?   En la calle",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_19_c": {
#     "valor": "",
#     "pregunta": "Durante los últimos doce meses, ¿ha experimentado usted malos tratos en alguno de estos lugares?   En los servicios de salud",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_19_d": {
#     "valor": "",
#     "pregunta": "Durante los últimos doce meses, ¿ha experimentado usted malos tratos en alguno de estos lugares?   En las oficinas de servicios del Estado",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_19_e": {
#     "valor": "",
#     "pregunta": "Durante los últimos doce meses, ¿ha experimentado usted malos tratos en alguno de estos lugares?   En las oficinas municipales",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_19_f": {
#     "valor": "",
#     "pregunta": "Durante los últimos doce meses, ¿ha experimentado usted malos tratos en alguno de estos lugares?   En bancos u oficinas comerciales (compañías de luz o agua, ISAPREs, compañías telefónicas, AFP, etc.)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_2": {
#     "valor": "",
#     "pregunta": "Considerando todas las cosas, ¿cuán satisfecho está usted con su vida en este momento? Por favor use esta tarjeta en que 1 significa que usted está “totalmente insatisfecho” y 10 significa que usted está “totalmente satisfecho”. ¿Dónde se ubicaría usted?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_20_a": {
#     "valor": "",
#     "pregunta": "Pensando en estas situaciones, ¿cuál cree usted es la razón más importante por la cual le ha tocado experimentar malos tratos?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_20_b": {
#     "valor": "",
#     "pregunta": "Pensando en estas situaciones, ¿cuál cree usted es la razón más importante por la cual le ha tocado experimentar malos tratos? ¿Y cuál sería la segunda más importante?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_21": {
#     "valor": "",
#     "pregunta": "Considerando todos los ingresos percibidos por su familia, esto es, todos los ingresos que reciben ustedes, ¿cuál de las frases que aparecen en esta tarjeta cree Ud. que se ajusta mejor a su situación de ingresos?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_22": {
#     "valor": "",
#     "pregunta": "Si tuviera que calificar el nivel de deudas que tiene en relación a sus ingreso actuales, usted diría que su nivel de endeudamiento es…",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "bienestar_3": {
#     "valor": "",
#     "pregunta": "Y en la misma escala, ¿cuán satisfechos con sus vidas cree usted que se encuentran el resto de los chilenos?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_a": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? La ciudad, pueblo o lugar donde vive",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_b": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Sus amistades",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_c": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Su salud y condición física",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_d": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Relación con su cónyuge, pareja o novio/a",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_e": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Sus actividades fuera del trabajo, hobbies y entretenciones",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_f": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Relación con sus hijos",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_g": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Su trabajo",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_h": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Su situación financiera",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_7_i": {
#     "valor": "",
#     "pregunta": "¿Cuán satisfecho o insatisfecho está usted con cada uno de los siguientes aspectos de su vida? Su vida en general",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_8_a": {
#     "valor": "",
#     "pregunta": "Si considera su vida en general, ¿qué tan feliz o infeliz diría usted que se siente, en términos generales? [Escala 1-4]",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_8_b": {
#     "valor": "",
#     "pregunta": "Si considera su vida en general, ¿qué tan feliz o infeliz diría usted que se siente, en términos generales? [Escala 1-7]",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "bienestar_9_a": {
#     "valor": "",
#     "pregunta": "Frente a los siguientes aspectos de su vida, dígame si éstos han ido mejorando, se han mantenido igual o han ido empeorando en los últimos 10 años. SU SITUACIÓN ECONÓMICA PERSONAL",
#     "alternativa": "-9",
#     "etiqueta": "No Responde"
#   },
#   "bienestar_9_b": {
#     "valor": "",
#     "pregunta": "Frente a los siguientes aspectos de su vida, dígame si éstos han ido mejorando, se han mantenido igual o han ido empeorando en los últimos 10 años. SU CAPACIDAD DE AHORRAR",
#     "alternativa": "-9",
#     "etiqueta": "No Responde"
#   },
#   "bienestar_9_c": {
#     "valor": "",
#     "pregunta": "Frente a los siguientes aspectos de su vida, dígame si éstos han ido mejorando, se han mantenido igual o han ido empeorando en los últimos 10 años. SU CAPACIDAD DE ACCEDER A UNA MEJOR SALUD PARA UD. Y SU FAMILIA",
#     "alternativa": "-9",
#     "etiqueta": "No Responde"
#   },
#   "bienestar_9_d": {
#     "valor": "",
#     "pregunta": "Frente a los siguientes aspectos de su vida, dígame si éstos han ido mejorando, se han mantenido igual o han ido empeorando en los últimos 10 años. SU CAPACIDAD DE ACCEDER A UNA MEJOR EDUCACIÓN PARA UD. O SUS HIJOS",
#     "alternativa": "-9",
#     "etiqueta": "No Responde"
#   },
#   "bienestar_9_e": {
#     "valor": "",
#     "pregunta": "Frente a los siguientes aspectos de su vida, dígame si éstos han ido mejorando, se han mantenido igual o han ido empeorando en los últimos 10 años. SU CAPACIDAD PARA COMPRAR BIENES Y SERVICIOS DURABLES",
#     "alternativa": "-9",
#     "etiqueta": "No Responde"
#   },
#   "bienestar_9_f": {
#     "valor": "",
#     "pregunta": "Frente a los siguientes aspectos de su vida, dígame si éstos han ido mejorando, se han mantenido igual o han ido empeorando en los últimos 10 años. SU CAPACIDAD DE ENDEUDARSE",
#     "alternativa": "-9",
#     "etiqueta": "No Responde"
#   },
#   "cambio_hora_1": {
#     "valor": "",
#     "pregunta": "¿Qué prefiere usted: que el sol salga más temprano en la mañana y que oscurezca más temprano o que el sol salga más tarde en la mañana y se oscurezca más tarde?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "cambio_hora_2": {
#     "valor": "",
#     "pregunta": "¿Qué tan de acuerdo o en desacuerdo está usted con que la hora se ajuste de tal forma que tengamos un horario distinto en verano y en invierno?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_10": {
#     "valor": "",
#     "pregunta": "Cuando Ud. mantiene una firme opinio?n poli?tica, ¿con que? frecuencia intenta persuadir a sus amigos, parientes o compan?eros de trabajo de compartir sus opiniones?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_11_a": {
#     "valor": "",
#     "pregunta": "Pensando sobre la poli?tica en Chile, ¿que? tanto esta? de acuerdo o en desacuerdo con las siguientes afirmaciones? LOS PARTIDOS POLITICOS ALIENTAN A LA GENTE A SER ACTIVOS EN POLITICA",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_11_b": {
#     "valor": "",
#     "pregunta": "Pensando sobre la poli?tica en Chile, ¿que? tanto esta? de acuerdo o en desacuerdo con las siguientes afirmaciones? LOS PARTIDOS POLITICOS NO LE DAN AL VOTANTE UNA VERDADERA ELECCION ENTRE POLITICAS PUBLICAS ALTERNATIVAS",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_11_c": {
#     "valor": "",
#     "pregunta": "Pensando sobre la poli?tica en Chile, ¿que? tanto esta? de acuerdo o en desacuerdo con las siguientes afirmaciones? LOS PLEBISCITOS SON UNA BUENA FORMA DE DECIDIR ASUNTOS POLITICOS IMPORTANTES",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_12": {
#     "valor": "",
#     "pregunta": "Pensando en las u?ltimas elecciones nacionales en Chile, ¿que? tan honestas fueron con respecto al conteo y reporte de los votos?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_13": {
#     "valor": "",
#     "pregunta": "Pensando en las u?ltimas elecciones nacionales en Chile, ¿que? tan justas fueron con respecto a la oportunidad para que los distintos candidatos y grupos hicieran campan?a?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_14": {
#     "valor": "",
#     "pregunta": "Pensando en el servicio pu?blico en Chile, ¿que? tan comprometidos esta?n sus funcionarios para servir a la gente?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_15": {
#     "valor": "",
#     "pregunta": "Cuando el servicio pu?blico en Chile comete errores serios, ¿que? tan probable es que ellos los corregira?n?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_16": {
#     "valor": "",
#     "pregunta": "Y, ¿qué tan extendida piensa Ud. que está la corrupción en el servicio público en Chile?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_17_a": {
#     "valor": "",
#     "pregunta": "En general, en una escala del 0 al 10, en la cual 0 es muy mal y 10 muy bien. ¿Que? tan bien funciona la democracia en Chile actualmente?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_17_b": {
#     "valor": "",
#     "pregunta": "En general, en una escala del 0 al 10, en la cual 0 es muy mal y 10 muy bien. ¿Y hace 10 an?os?, ¿que? tan bien funcionaba la democracia en ese entonces en Chile?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_17_c": {
#     "valor": "",
#     "pregunta": "En general, en una escala del 0 al 10, en la cual 0 es muy mal y 10 muy bien. ¿Y dentro de 10 an?os? ¿Que? tan bien piensa Ud. que la democracia funcionara? en ese entonces en Chile?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_18": {
#     "valor": "",
#     "pregunta": "A continuacio?n esta?n algunos puntos de vista sobre el sistema poli?tico de Chile. ¿Cua?l de estas declaraciones se acerca ma?s a su punto de vista?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_19": {
#     "valor": "",
#     "pregunta": "¿Con qué frecuencia usted utiliza los medios de comunicación, incluyendo la televisión, diarios, radio e Internet, para obtener noticias o información política?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_1_a": {
#     "valor": "",
#     "pregunta": "A continuación le voy a leer algunas afirmaciones y Ud. me dirá cuán de acuerdo o en desacuerdo está con cada una de ellas.  ¿Cuán de acuerdo o en desacuerdo está con la afirmación que dice: “EN CHILE LAS PERSONAS RESPETAN LA OPINION DE LOS DEMAS”",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_1_b": {
#     "valor": "",
#     "pregunta": "A continuación le voy a leer algunas afirmaciones y Ud. me dirá cuán de acuerdo o en desacuerdo está con cada una de ellas. ¿Cuán de acuerdo o en desacuerdo está con la afirmación que dice: “EN CHILE ES DIFICIL QUE LAS PERSONAS HAGAN ALGO POR LOS DEMAS SI NO ESPERAN OBTENER ALGO A CAMBIO”.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_1_c": {
#     "valor": "",
#     "pregunta": "A continuación le voy a leer algunas afirmaciones y Ud. me dirá cuán de acuerdo o en desacuerdo está con cada una de ellas. ¿Cuán de acuerdo o en desacuerdo está con la afirmación que dice: “EN CHILE ES FACIL HACER BUENOS AMIGOS”",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_1_d": {
#     "valor": "",
#     "pregunta": "A continuación le voy a leer algunas afirmaciones y Ud. me dirá cuán de acuerdo o en desacuerdo está con cada una de ellas. ¿Cuán de acuerdo o en desacuerdo está con la afirmación que dice: “EN CHILE LAS PERSONAS PASAN A LLEVAR A LOS DEMAS CON TAL DE CONSEGUIR SUS OBJETIVOS”.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_2": {
#     "valor": "",
#     "pregunta": "La posibilidad de introducir el servicio militar voluntario es otro de los aspectos que se ha estado discutiendo en el país en el último tiempo. Respecto de este tema ¿está Ud. de acuerdo con que el actual Servicio Militar Obligatorio se reemplace por un sistema voluntario?",
#     "alternativa": "-9",
#     "etiqueta": "No Contesta"
#   },
#   "ciudadania_20": {
#     "valor": "",
#     "pregunta": "En promedio, con cuántas personas tiene usted contacto en un típico día de semana, incluyendo a las personas con las que usted vive. Estamos interesados en contacto uno a uno, incluyendo todas las personas con quienes usted conversa, habla o discute sobre distintos asuntos. Este contacto puede ser cara a cara, por teléfono, por correo, o por Internet. Incluya sólo las personas que usted conoce. Por favor, seleccione una de las siguientes categorías que coincida mejor con su estimación.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_21": {
#     "valor": "",
#     "pregunta": "En política las personas hablan de izquierda y derecha. ¿Dónde se ubicaría usted en una escala que va de 0 a 10 donde 0 representa izquierda y 10 representa derecha?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_22_a": {
#     "valor": "",
#     "pregunta": "Pensando en sus padres a la edad que usted tiene ahora y siguiendo con la misma escala, me gustaría pedirle que por favor los clasificara en esta misma escala señalando dónde cree Ud que se ubican ellos. Veamos, ¿dónde ubicaría usted a…? Su madre",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_22_b": {
#     "valor": "",
#     "pregunta": "Pensando en sus padres a la edad que usted tiene ahora y siguiendo con la misma escala, me gustaría pedirle que por favor los clasificara en esta misma escala señalando dónde cree Ud que se ubican ellos. Veamos, ¿dónde ubicaría usted a…? Su padre",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_23": {
#     "valor": "",
#     "pregunta": "Cuando usted se reúne con sus amigos, parientes o compañeros de trabajo, ¿con qué frecuencia discuten sobre política?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_24": {
#     "valor": "",
#     "pregunta": "Cuando usted tiene opinión política decidida, ¿con qué frecuencia intenta persuadir a sus amigos, parientes o compañeros de trabajo para que compartan su opinión?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "ciudadania_25_a": {
#     "valor": "",
#     "pregunta": "En promedio, ¿con qué frecuencia usted…? Lee la sección política de un diario",
#     "alternativa": "-9",
#     "etiqueta": "No responde"
#   },
# ...
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_14_e": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del sistema de transporte de su ciudad/zona en los siguientes aspectos? CERCANÍA DE LOS PARADEROS A SU HOGAR Y TRABAJO.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_14_f": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del sistema de transporte de su ciudad/zona en los siguientes aspectos? CALIDAD DE LOS BUSES.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_14_g": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del sistema de transporte de su ciudad/zona en los siguientes aspectos? CANTIDAD DE TRANSBORDOS.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_14_h": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del sistema de transporte de su ciudad/zona en los siguientes aspectos? CANTIDAD DE DINERO QUE GASTA.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_15": {
#     "valor": "",
#     "pregunta": "Y, ¿con qué frecuencia usaba Ud. las micros amarillas?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_16": {
#     "valor": "",
#     "pregunta": "Considerando todo lo bueno y todo lo malo, ¿los viajes son mejores o son peores que antes?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_17": {
#     "valor": "",
#     "pregunta": "¿Con qué frecuencia usa Ud. el transporte público?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_18": {
#     "valor": "",
#     "pregunta": "¿Con cuánta frecuencia usted sufre de acoso o abuso callejero?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (No leer)"
#   },
#   "transporte_19": {
#     "valor": "",
#     "pregunta": "¿En qué espacios usted sufre con mayor frecuencia acoso o abuso callejero?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (No leer)"
#   },
#   "transporte_1_a": {
#     "valor": "",
#     "pregunta": "En febrero de 2007 comenzó a funcionar el Transantiago. Por lo que Ud. sabe, ¿Ud. diría que el Transantiago ha funcionado bien, regular o mal? (sub muestra: regiones)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_2": {
#     "valor": "",
#     "pregunta": "¿Con qué frecuencia usa Ud. el Transantiago?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_a": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? TIEMPOS DE VIAJE.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_b": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? FORMA DE PAGO (LA TARJETA BIP).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_c": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? FRECUENCIA DE BUSES DURANTE EL DÍA.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_d": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? FRECUENCIA DE BUSES DURANTE LA NOCHE.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_e": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? CERCANÍA DE LOS PARADEROS A SU HOGAR Y TRABAJO.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_f": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? CALIDAD DE LOS BUSES.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_g": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? CALIDAD DEL SERVICIO DEL METRO.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_3_h": {
#     "valor": "",
#     "pregunta": "De acuerdo a su experiencia, ¿cómo calificaría el funcionamiento del Transantiago en los siguientes aspectos? CANTIDAD DE TRANSBORDOS.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_a": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? TIEMPOS DE VIAJE.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_b": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? FORMA DE PAGO (LA TARJETA BIP).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_c": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? FRECUENCIA DE BUSES DURANTE EL DÍA.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_d": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? FRECUENCIA DE BUSES DURANTE LA NOCHE.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_e": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? CERCANÍA DE LOS PARADEROS A SU HOGAR Y TRABAJO.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_f": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? CALIDAD DE LOS BUSES.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_g": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? CALIDAD DEL SERVICIO DEL METRO.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_4_h": {
#     "valor": "",
#     "pregunta": "¿Ud. diría que los siguientes aspectos del Transantiago han mejorado, han empeorado o se han mantenido igual que en un comienzo? CANTIDAD DE TRANSBORDOS.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_5_a": {
#     "valor": "",
#     "pregunta": "Comparando con el sistema anterior de las micros amarillas, hoy en día ¿Ud. …¿Se demora más, igual, o menos que antes en sus viajes habituales?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_5_b": {
#     "valor": "",
#     "pregunta": "Comparando con el sistema anterior de las micros amarillas, hoy en día ¿Ud. …¿Gasta más, igual, o menos que antes en sus viajes habituales?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_5_c": {
#     "valor": "",
#     "pregunta": "Comparando con el sistema anterior de las micros amarillas, hoy en día ¿Ud. …¿Hace más, igual o menos trasbordos que antes?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_5_d": {
#     "valor": "",
#     "pregunta": "Comparando con el sistema anterior de las micros amarillas, hoy en día ¿Ud. …¿Viaja más, igual o menos cómodo que antes?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_5_e": {
#     "valor": "",
#     "pregunta": "Comparando con el sistema anterior de las micros amarillas, hoy en día ¿Ud. …¿Viaja más, igual o menos seguro que antes?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_6": {
#     "valor": "",
#     "pregunta": "La gente que Ud. conoce, ¿paga la tarifa de los buses siempre, a veces o nunca?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_7": {
#     "valor": "",
#     "pregunta": "Y Ud., ¿paga la tarifa de los buses siempre, a veces o nunca?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_8": {
#     "valor": "",
#     "pregunta": "¿Ud. preferiría que…?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_9": {
#     "valor": "",
#     "pregunta": "Y ¿Ud. cree que los problemas de las regiones han sido dejados de lado por el Transantiago, o no han sido dejados de lado? (sub muestra: Región Metropolitana)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "transporte_9_a": {
#     "valor": "",
#     "pregunta": "Y ¿Ud. cree que los problemas de las regiones han sido dejados de lado por el Transantiago, o no han sido dejados de lado? (sub muestra: regiones)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_1": {
#     "valor": "",
#     "pregunta": "Considere una casa y un departamento de igual tamaño en metros cuadrados. Si a Ud. Le significara pagar lo mismo por vivir en una casa o en un departamento, ¿cuál de los dos preferiría para vivir?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_10_a": {
#     "valor": "",
#     "pregunta": "En la siguiente tarjeta Ud. encontrará algunas de las soluciones más mencionadas por los especialistas para terminar con la congestión o tacos en Santiago. Por favor señale las 2 soluciones que Ud. cree que serían más efectivas para terminar con la congestión en Santiago. Veamos, ¿cuál cree Ud. que sería la más efectiva?.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_10_b": {
#     "valor": "",
#     "pregunta": "¿Y la segunda que Ud. considera como más efectiva, cual sería?.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_11": {
#     "valor": "",
#     "pregunta": "Suponga que Ud. dispone de un auto y de un servicio público de transporte. Si a Ud. Le significara lo mismo en tiempo y comodidad realizar sus viajes en su auto o en transporte público, ¿preferiría Ud. viajar en su auto o viajar en transporte público?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_2_a": {
#     "valor": "",
#     "pregunta": "De acuerdo a estas alternativas, por favor dígame ¿por qué preferiría Ud. vivir en una casa? Por favor dígame sólo una. (Sub muestra : código 1 en P20)",
#     "alternativa": "-8",
#     "etiqueta": "No sabe"
#   },
#   "vivienda_2_b": {
#     "valor": "",
#     "pregunta": "De acuerdo a estas alternativas, por favor dígame, ¿por qué preferiría Ud. vivir en un departamento? Por favor dígame sólo una. (Sub muestra : código 2 en P20)",
#     "alternativa": "3",
#     "etiqueta": "Otra"
#   },
#   "vivienda_3": {
#     "valor": "",
#     "pregunta": "¿Se han cambiado ustedes de casa o departamento en los últimos tres años? Por favor respóndame utilizando las alternativas de la tarjeta.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "vivienda_3_a": {
#     "valor": "",
#     "pregunta": "¿Cuál fue el principal motivo del cambio? (Sub muestra: códigos 1, 2, 3, 4 en P23)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_4": {
#     "valor": "",
#     "pregunta": "¿Cuál es la situación de propiedad de esta vivienda?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_5": {
#     "valor": "",
#     "pregunta": "En la tarjeta se describen los programas de ayuda para la vivienda, entregados por el gobierno o las municipalidades. ¿recibió el actual propietario de esta vivienda alguno de estos programas de ayuda?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_5_a": {
#     "valor": "",
#     "pregunta": "¿Cuál de los programas de ayuda recibió? (Sub muestra: código 1 en P26)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_5_b": {
#     "valor": "",
#     "pregunta": "¿En qué año compró o recibió el actual propietario esta vivienda? (Sub muestra: código 1 en P26)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_6_a": {
#     "valor": "",
#     "pregunta": "A continuación le leeré una serie de mejoras que se pueden realizar en una vivienda. Para cada una de ellas quiero que por favor me diga si en esta vivienda se han realizado o no. (Sub muestra: código 1 en P26) Colocación de rejas en las ventanas.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_6_b": {
#     "valor": "",
#     "pregunta": "A continuación le leeré una serie de mejoras que se pueden realizar en una vivienda. Para cada una de ellas quiero que por favor me diga si en esta vivienda se han realizado o no. (Sub muestra: código 1 en P26) Ampliación o remodelación de un recinto de la vivienda (baño, cocina, piezas).",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_6_c": {
#     "valor": "",
#     "pregunta": "A continuación le leeré una serie de mejoras que se pueden realizar en una vivienda. Para cada una de ellas quiero que por favor me diga si en esta vivienda se han realizado o no. (Sub muestra: código 1 en P26) Construcción de un recinto adicional para la vivienda, esto es, un nuevo baño, cocina o pieza.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_6_d": {
#     "valor": "",
#     "pregunta": "A continuación le leeré una serie de mejoras que se pueden realizar en una vivienda. Para cada una de ellas quiero que por favor me diga si en esta vivienda se han realizado o no. (Sub muestra: código 1 en P26) Colocación de reja exterior, cerco.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_6_e": {
#     "valor": "",
#     "pregunta": "A continuación le leeré una serie de mejoras que se pueden realizar en una vivienda. Para cada una de ellas quiero que por favor me diga si en esta vivienda se han realizado o no. (Sub muestra: código 1 en P26) Cambio del piso de algún recinto de la vivienda.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_6_f": {
#     "valor": "",
#     "pregunta": "A continuación le leeré una serie de mejoras que se pueden realizar en una vivienda. Para cada una de ellas quiero que por favor me diga si en esta vivienda se han realizado o no. (Sub muestra: código 1 en P26) Pintura nueva interior o exterior.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_6_g": {
#     "valor": "",
#     "pregunta": "A continuación le leeré una serie de mejoras que se pueden realizar en una vivienda. Para cada una de ellas quiero que por favor me diga si en esta vivienda se han realizado o no. (Sub muestra: código 1 en P26) Construcción de un local de trabajo (tienda, taller) o almacén.",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_7": {
#     "valor": "",
#     "pregunta": "¿Cuántos metros cuadrados construidos útiles tiene esta vivienda? (Sub muestra: código 1 en P26)",
#     "alternativa": "-9",
#     "etiqueta": "No contesta"
#   },
#   "vivienda_8": {
#     "valor": "",
#     "pregunta": "En general, ¿con qué frecuencia utiliza locomoción colectiva, es decir, micros, taxis y taxis colectivos, para desplazarse?",
#     "alternativa": "-9",
#     "etiqueta": "No contesta (no leer)"
#   },
#   "vivienda_9": {
#     "valor": "",
#     "pregunta": "Pensando en su caso particular, ¿diría Ud. que el nuevo plan de vías segregadas o exclusivas para la locomoción colectiva ha reducido sus tiempos de desplazamiento, o sus tiempos de desplazamiento no han cambiado?",
#     "alternativa": "-8",
#     "etiqueta": "No sabe"
#   },
#   "zona_u_r": {
#     "valor": "1",
#     "pregunta": "Zona Urbano/Rural",
#     "alternativa": "2",
#     "etiqueta": "Rural"
#   }
# }
